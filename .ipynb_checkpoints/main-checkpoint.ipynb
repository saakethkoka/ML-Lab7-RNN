# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, Dense, LSTM, Bidirectional, Dropout
from tensorflow.keras.models import Sequential

# %%
# https://www.kaggle.com/datasets/kazanova/sentiment140?resource=download
data = pd.read_csv("training.1600000.processed.noemoticon.csv", encoding="ISO-8859-1", header=None)
data = data[[0,5]]
data.columns = ["sentiment", "text"]

data["sentiment"] = data["sentiment"].replace(4, 1)

# %%
# Calculating number of words in each tweet:
data["word_count"] = data["text"].apply(lambda x: len(x.split()))
# plot histogram of number of words:
plt.hist(data["word_count"], bins=20)
plt.title("Histogram of number of words in each tweet")
plt.xlabel("Number of words")
plt.ylabel("Number of tweets")
data.drop("word_count", axis=1, inplace=True)

# %% [markdown]
# Due to twitter forcably limiting the number of characters, the number of words in each tweet are fairly constrained to under 30 words per tweet. For this reason we find it appropriate to use 30 word fixed length sequcnes for our models.

# %%
data.sentiment.value_counts()
# Out:
# 0    800000
# 1    800000
# Name: sentiment, dtype: int64

# %% [markdown]
# ## Metrics
# #### Accuracy:
#
# Because the dataset is balanced, accuracy is an appropriate metric to use on our dataset. Our models will potentially be used to measure sentiment regarding certain topics on twitter and accuracy is a good measure to gauge the classification performance for that task.

# %% [markdown]
# ## Splitting:
#
# We will use a standard 80-20 train test split. We have enough data, 1.6M tweets split evently amoung two classes is enough data to train and evaluate with.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data["text"], data["sentiment"], test_size=0.2, random_state=42)

# %% [markdown]
# ## Creating Embedding Layer:

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

X_train_sequences = tokenizer.texts_to_sequences(X_train)
X_test_sequences = tokenizer.texts_to_sequences(X_test)

word_index = tokenizer.word_index

print('Found %s unique tokens.' % (len(word_index)))
# Out:
# Found 594848 unique tokens.

# %%
# %%time
EMBED_SIZE = 200
# the embed size should match the file you load glove from
embeddings_index = {}
f = open('glove.twitter.27B.200d.txt')
# save key/array pairs of the embeddings
#  the key of the dictionary is the word, the array is the embedding
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))

# now fill in the matrix, using the ordering from the
#  keras word tokenizer from before
found_words = 0
embedding_matrix = np.zeros((len(word_index) + 1, EMBED_SIZE))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be ALL-ZEROS
        embedding_matrix[i] = embedding_vector
        found_words = found_words+1

print("Embedding Shape:",embedding_matrix.shape, "\n",
      "Total words found:",found_words, "\n",
      "Percentage:",100*found_words/embedding_matrix.shape[0])
# Out:
# Found 1193514 word vectors.
# Embedding Shape: (594849, 200)
#  Total words found: 121078
#  Percentage: 20.35440927025178
# CPU times: user 1min 8s, sys: 2.35 s, total: 1min 11s
# Wall time: 1min 11s

# %%
X_train = pad_sequences(X_train_sequences, maxlen=30)
X_test = pad_sequences(X_test_sequences, maxlen=30)

# %%
MAX_ART_LEN = 30

# save this embedding now
embedding_layer = Embedding(len(word_index) + 1,
                            EMBED_SIZE,
                            weights=[embedding_matrix],# here is the embedding getting saved
                            input_length=MAX_ART_LEN,
                            trainable=False)

# %% [markdown]
# ## Modeling:

# %%
def plot_history(history):
    # plot history of the model:
    fig = plt.figure(figsize=(10, 8))
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='validate')
    plt.legend()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss over epochs')

# %%
rnn1 = Sequential()
rnn1.add(embedding_layer)
rnn1.add(LSTM(100))
rnn1.add(Dense(1, activation='sigmoid'))
rnn1.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
rnn1.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 30, 200)           118969800
#
#  lstm_7 (LSTM)               (None, 100)               120400
#
#  dense_7 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 119,090,301
# Trainable params: 120,501
# Non-trainable params: 118,969,800
# _________________________________________________________________

# %%
history_rnn_1 = rnn1.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test), batch_size=2048)
# Out:
# Epoch 1/20
# 625/625 [==============================] - 12s 16ms/step - loss: 0.4554 - accuracy: 0.7828 - val_loss: 0.4227 - val_accuracy: 0.8040
# Epoch 2/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4117 - accuracy: 0.8104 - val_loss: 0.4067 - val_accuracy: 0.8134
# Epoch 3/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3972 - accuracy: 0.8187 - val_loss: 0.3966 - val_accuracy: 0.8187
# Epoch 4/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3877 - accuracy: 0.8239 - val_loss: 0.3903 - val_accuracy: 0.8224
# Epoch 5/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3802 - accuracy: 0.8280 - val_loss: 0.3886 - val_accuracy: 0.8233
# Epoch 6/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3745 - accuracy: 0.8313 - val_loss: 0.3823 - val_accuracy: 0.8266
# Epoch 7/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3687 - accuracy: 0.8342 - val_loss: 0.3809 - val_accuracy: 0.8276
# Epoch 8/20
# 625/625 [==============================] - 10s 15ms/step - loss: 0.3643 - accuracy: 0.8366 - val_loss: 0.3860 - val_accuracy: 0.8251
# Epoch 9/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3599 - accuracy: 0.8392 - val_loss: 0.3782 - val_accuracy: 0.8293
# Epoch 10/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3563 - accuracy: 0.8409 - val_loss: 0.3783 - val_accuracy: 0.8290
# Epoch 11/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3523 - accuracy: 0.8431 - val_loss: 0.3805 - val_accuracy: 0.8280
# Epoch 12/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3491 - accuracy: 0.8446 - val_loss: 0.3831 - val_accuracy: 0.8268
# Epoch 13/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3461 - accuracy: 0.8461 - val_loss: 0.3787 - val_accuracy: 0.8293
# Epoch 14/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3430 - accuracy: 0.8480 - val_loss: 0.3794 - val_accuracy: 0.8294
# Epoch 15/20
# 625/625 [==============================] - 10s 15ms/step - loss: 0.3401 - accuracy: 0.8492 - val_loss: 0.3797 - val_accuracy: 0.8297
# Epoch 16/20
# 625/625 [==============================] - 10s 15ms/step - loss: 0.3372 - accuracy: 0.8509 - val_loss: 0.3817 - val_accuracy: 0.8295
# Epoch 17/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3349 - accuracy: 0.8523 - val_loss: 0.3813 - val_accuracy: 0.8288
# Epoch 18/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3324 - accuracy: 0.8535 - val_loss: 0.3856 - val_accuracy: 0.8284
# Epoch 19/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3298 - accuracy: 0.8548 - val_loss: 0.3852 - val_accuracy: 0.8278
# Epoch 20/20
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3274 - accuracy: 0.8559 - val_loss: 0.3868 - val_accuracy: 0.8267

# %%
plot_history(history_rnn_1)

# %%
rnn2 = Sequential()
rnn2.add(embedding_layer)
rnn2.add(LSTM(100, dropout=0.2))
rnn2.add(Dense(1, activation='sigmoid'))
rnn2.compile(loss='binary_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])
rnn2.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 30, 200)           118969800
#
#  lstm_9 (LSTM)               (None, 100)               120400
#
#  dense_9 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 119,090,301
# Trainable params: 120,501
# Non-trainable params: 118,969,800
# _________________________________________________________________

# %%
history_rnn_2 = rnn2.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test), batch_size=2048)
# Out:
# Epoch 1/50
# 625/625 [==============================] - 13s 17ms/step - loss: 0.4713 - accuracy: 0.7727 - val_loss: 0.4266 - val_accuracy: 0.8012
# Epoch 2/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4288 - accuracy: 0.8001 - val_loss: 0.4091 - val_accuracy: 0.8118
# Epoch 3/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.4145 - accuracy: 0.8086 - val_loss: 0.4012 - val_accuracy: 0.8157
# Epoch 4/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4054 - accuracy: 0.8138 - val_loss: 0.3932 - val_accuracy: 0.8205
# Epoch 5/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3987 - accuracy: 0.8174 - val_loss: 0.3897 - val_accuracy: 0.8230
# Epoch 6/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3928 - accuracy: 0.8209 - val_loss: 0.3860 - val_accuracy: 0.8248
# Epoch 7/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3886 - accuracy: 0.8232 - val_loss: 0.3857 - val_accuracy: 0.8242
# Epoch 8/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.3849 - accuracy: 0.8251 - val_loss: 0.3817 - val_accuracy: 0.8271
# Epoch 9/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3818 - accuracy: 0.8273 - val_loss: 0.3801 - val_accuracy: 0.8287
# Epoch 10/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3791 - accuracy: 0.8286 - val_loss: 0.3776 - val_accuracy: 0.8297
# Epoch 11/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.3767 - accuracy: 0.8297 - val_loss: 0.3785 - val_accuracy: 0.8299
# Epoch 12/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3745 - accuracy: 0.8309 - val_loss: 0.3766 - val_accuracy: 0.8303
# Epoch 13/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.3722 - accuracy: 0.8321 - val_loss: 0.3751 - val_accuracy: 0.8309
# Epoch 14/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3706 - accuracy: 0.8331 - val_loss: 0.3743 - val_accuracy: 0.8314
# Epoch 15/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3686 - accuracy: 0.8340 - val_loss: 0.3758 - val_accuracy: 0.8312
# Epoch 16/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3675 - accuracy: 0.8345 - val_loss: 0.3726 - val_accuracy: 0.8323
# Epoch 17/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3660 - accuracy: 0.8355 - val_loss: 0.3753 - val_accuracy: 0.8315
# Epoch 18/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3646 - accuracy: 0.8364 - val_loss: 0.3733 - val_accuracy: 0.8321
# Epoch 19/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.3634 - accuracy: 0.8367 - val_loss: 0.3735 - val_accuracy: 0.8328
# Epoch 20/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.3624 - accuracy: 0.8374 - val_loss: 0.3731 - val_accuracy: 0.8334
# Epoch 21/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3614 - accuracy: 0.8379 - val_loss: 0.3735 - val_accuracy: 0.8325
# Epoch 22/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3600 - accuracy: 0.8386 - val_loss: 0.3724 - val_accuracy: 0.8330
# Epoch 23/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3593 - accuracy: 0.8390 - val_loss: 0.3725 - val_accuracy: 0.8336
# Epoch 24/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.3589 - accuracy: 0.8391 - val_loss: 0.3719 - val_accuracy: 0.8337
# Epoch 25/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3577 - accuracy: 0.8396 - val_loss: 0.3731 - val_accuracy: 0.8325
# Epoch 26/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3571 - accuracy: 0.8401 - val_loss: 0.3731 - val_accuracy: 0.8329
# Epoch 27/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.3563 - accuracy: 0.8406 - val_loss: 0.3714 - val_accuracy: 0.8342
# Epoch 28/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3553 - accuracy: 0.8411 - val_loss: 0.3740 - val_accuracy: 0.8340
# Epoch 29/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3550 - accuracy: 0.8414 - val_loss: 0.3730 - val_accuracy: 0.8333
# Epoch 30/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3543 - accuracy: 0.8415 - val_loss: 0.3745 - val_accuracy: 0.8335
# Epoch 31/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3538 - accuracy: 0.8421 - val_loss: 0.3718 - val_accuracy: 0.8337
# Epoch 32/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3531 - accuracy: 0.8422 - val_loss: 0.3730 - val_accuracy: 0.8336
# Epoch 33/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3527 - accuracy: 0.8426 - val_loss: 0.3716 - val_accuracy: 0.8340
# Epoch 34/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3518 - accuracy: 0.8429 - val_loss: 0.3746 - val_accuracy: 0.8340
# Epoch 35/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3517 - accuracy: 0.8432 - val_loss: 0.3725 - val_accuracy: 0.8344
# Epoch 36/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3507 - accuracy: 0.8437 - val_loss: 0.3728 - val_accuracy: 0.8344
# Epoch 37/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3507 - accuracy: 0.8435 - val_loss: 0.3736 - val_accuracy: 0.8335
# Epoch 38/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3504 - accuracy: 0.8438 - val_loss: 0.3745 - val_accuracy: 0.8331
# Epoch 39/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3497 - accuracy: 0.8439 - val_loss: 0.3725 - val_accuracy: 0.8341
# Epoch 40/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3497 - accuracy: 0.8441 - val_loss: 0.3746 - val_accuracy: 0.8337
# Epoch 41/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.3492 - accuracy: 0.8444 - val_loss: 0.3725 - val_accuracy: 0.8346
# Epoch 42/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3491 - accuracy: 0.8447 - val_loss: 0.3729 - val_accuracy: 0.8342
# Epoch 43/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3483 - accuracy: 0.8447 - val_loss: 0.3734 - val_accuracy: 0.8337
# Epoch 44/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3483 - accuracy: 0.8450 - val_loss: 0.3739 - val_accuracy: 0.8335
# Epoch 45/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3478 - accuracy: 0.8451 - val_loss: 0.3742 - val_accuracy: 0.8343
# Epoch 46/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3474 - accuracy: 0.8452 - val_loss: 0.3739 - val_accuracy: 0.8335
# Epoch 47/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3472 - accuracy: 0.8453 - val_loss: 0.3745 - val_accuracy: 0.8341
# Epoch 48/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3470 - accuracy: 0.8452 - val_loss: 0.3767 - val_accuracy: 0.8324
# Epoch 49/50
# 625/625 [==============================] - 10s 17ms/step - loss: 0.3464 - accuracy: 0.8455 - val_loss: 0.3742 - val_accuracy: 0.8340
# Epoch 50/50
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3460 - accuracy: 0.8459 - val_loss: 0.3737 - val_accuracy: 0.8345

# %%
plot_history(history_rnn_2)
